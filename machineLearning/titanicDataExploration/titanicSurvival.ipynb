# %% [markdown]
# # Titanic Dataset Exploration

# %% [markdown]
# ## Part 1: Data Exploration

# %% [markdown]
# Load in the titanic dataset from Seaborn. Document the columns that are missing data both numberically (via a count) and visually (via a sns heatmap). Document the categorical values. Answer the following questions:
# - Did more women or men die on the Titanic?
# - Which passenger class was more likely to survive?
# - What does the distribution of fare look like?
# - What does the distribution of non-null age values look like?
# - What is the median age of each passenger class(pclass)? Visualize this in a box plot.

# %%
# import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_predict
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import SGDClassifier
from sklearn import svm
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, precision_score, recall_score
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

# %%
# load in the seaborn titanic dataset
titanic= sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# get info on the data set to get a quick glance at missing values
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
# create heatmap to look at missing values
sns.heatmap(titanic.isnull(), cmap= 'viridis')
plt.show()

# %%
# create a series showing the number of non-null counts in each feature
indices= titanic.columns
non_null= titanic.count(axis= 0)
non_null.rename('non_null', inplace= True)
non_null
# Out:
# survived       891
# pclass         891
# sex            891
# age            714
# sibsp          891
# parch          891
# fare           891
# embarked       889
# class          891
# who            891
# adult_male     891
# deck           203
# embark_town    889
# alive          891
# alone          891
# Name: non_null, dtype: int64

# %%
# create a series showing the number of null counts in each feature
null_counts= pd.Series(data= titanic.shape[0] - non_null.values , index= indices, name= 'null')
null_counts
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# Name: null, dtype: int64

# %%
# merge the two series together into a dataframe
counts= pd.concat([non_null, null_counts], axis= 1)
counts
# Out:
#              non_null  null
# survived          891     0
# pclass            891     0
# sex               891     0
# age               714   177
# sibsp             891     0
# parch             891     0
# fare              891     0
# embarked          889     2
# class             891     0
# who               891     0
# adult_male        891     0
# deck              203   688
# embark_town       889     2
# alive             891     0
# alone             891     0

# %% [markdown]
# The following columns are missing data:
# - age (177 missing values)
# - deck (688 missing values)
# - embarked (2 missing values)
# - embarked_town (2 missing values)

# %% [markdown]
# All of the column values are categorical variables except for:
# - age
# - fare

# %% [markdown]
# ### Question Exploration

# %% [markdown]
# Did more women or men die on the Titanic?

# %%
# plot a bar chart to visualize suvival rate vs sex
sns.set()
plt.figure(num= 2)

sns.barplot(data= titanic, x= 'sex', y= 'survived', hue= 'sex', errorbar= None)
plt.title('Survival Rate by Sex')
plt.xlabel('Sex')
plt.ylabel('Survived (proportion)')

plt.show()

# %% [markdown]
# A larger proportion of females survived vs males. Therefore, more men died on the Titanic.

# %%
# to verify take a look at actual total counts
titanic.value_counts('sex')
# Out:
# sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
# then look at actual counts of survived vs didn't survive between sexes
titanic.value_counts(['sex', 'survived'])
# Out:
# sex     survived
# male    0           468
# female  1           233
# male    1           109
# female  0            81
# Name: count, dtype: int64

# %% [markdown]
# Which passenger class was more likely to surive?

# %%
# plot a bar chart to visualize passenger class vs survived
sns.set()
plt.figure(num= 3)

sns.barplot(data= titanic, x= 'pclass', y= 'survived', hue= 'pclass', palette= 'pastel', errorbar= None)
plt.title('Survival Rate by Passenger Class')
plt.xlabel('Passenger Class')
plt.ylabel('Survived (proportion)')

plt.show()

# %% [markdown]
# Passenger class 1 had the higher survival rate, and thus was the most likely to survive.

# %% [markdown]
# What does the distribution of fare look like?

# %%
# plot the distribution of fare
plt.figure(num= 4)

sns.histplot(data= titanic, x= 'fare')
plt.title('Passenger Fare')
plt.xlabel('Fare ($)')
plt.ylabel('Count')

plt.show()

# %%
# look at data for fares under 300, to ignore the data point(s) above 500
plt.figure(num= 5)

fare= 'fare'
t_filt= titanic[titanic[fare] < 300]

sns.kdeplot(data= t_filt, x= 'fare')
plt.title('Passenger Fare Distribution for Fare < $300')
plt.xlabel('Fare ($)')

plt.show()

# %%
titanic['fare'].median(), titanic['fare'].mean()
# Out:
# (14.4542, 32.204207968574636)

# %% [markdown]
# The majority of fares fall into the range of about (0, 50). However, the data is skewed right, and this is confirmed by looking at the actual values of the median and mean of the fares.

# %% [markdown]
# What does the distribution of nun-null age values look like?

# %%
# create a df of non-null age values
ages= pd.DataFrame(titanic['age'].dropna(), columns=['age'])
ages
# Out:
#       age
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# ..    ...
# 885  39.0
# 886  27.0
# 887  19.0
# 889  26.0
# 890  32.0
#
# [714 rows x 1 columns]

# %%
# plot non-null age distribution
plt.figure(num= 6)

sns.displot(data= ages, x= 'age')
plt.title('Passenger Ages')
plt.xlabel('Age (yrs)')

plt.show()

# %% [markdown]
# What is the median age of each passenger class(pclass)? Visualize this in a box plot.

# %%
# calculate median age of each passenger class
class_age= titanic.groupby(['pclass'])
class_age['age'].median()
# Out:
# pclass
# 1    37.0
# 2    29.0
# 3    24.0
# Name: age, dtype: float64

# %%
# plot median age per passenger class in a box plot
plt.figure(num= 7)

sns.boxplot(data= titanic, x= 'pclass', y= 'age', hue= 'pclass', palette= 'pastel')
plt.title('Age Distribution of Each Passenger Class')
plt.xlabel('Passenger Class')
plt.ylabel('Age (yrs)')

plt.show()

# %% [markdown]
# ## Part 2: Data Cleansing

# %%
# revist our dataset
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# remove the deck feature (since it had so many missing values)
titanic.drop('deck', axis= 1, inplace= True)
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male  embark_town alive  alone
# 0    man        True  Southampton    no  False
# 1  woman       False    Cherbourg   yes  False
# 2  woman       False  Southampton   yes   True
# 3  woman       False  Southampton   yes  False
# 4    man        True  Southampton    no   True

# %%
# define a lambda function to impute age using the median of the passenger class computed earlier

# This was what was messing my code up to begin with:

#titanic.age.fillna(lambda x: x.groupby('pclass').age.median(), inplace= True)    # This was causing the fill in
# value to be the lambda object, which was then messing up everything that follows, syntax is missing something or
# messed up somewhere, had to do it the way below without the labmda function to at least get everything else working

# %%
# impute age using the median of the passenger class
titanic.age.fillna(titanic.groupby('pclass').age.transform(np.mean), inplace= True)
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          891 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  embark_town  889 non-null    object
#  12  alive        891 non-null    object
#  13  alone        891 non-null    bool
# dtypes: bool(2), category(1), float64(2), int64(4), object(5)
# memory usage: 79.4+ KB

# %%
# create heatmap to re-look at missing values
sns.heatmap(titanic.isnull(), cmap= 'viridis')
plt.show()

# %% [markdown]
# There are no longer any null values in the age feature.

# %%
# drop remaining records with null values
titanic.dropna(axis= 0, inplace= True)
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 889 entries, 0 to 890
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     889 non-null    int64
#  1   pclass       889 non-null    int64
#  2   sex          889 non-null    object
#  3   age          889 non-null    float64
#  4   sibsp        889 non-null    int64
#  5   parch        889 non-null    int64
#  6   fare         889 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        889 non-null    category
#  9   who          889 non-null    object
#  10  adult_male   889 non-null    bool
#  11  embark_town  889 non-null    object
#  12  alive        889 non-null    object
#  13  alone        889 non-null    bool
# dtypes: bool(2), category(1), float64(2), int64(4), object(5)
# memory usage: 86.1+ KB

# %% [markdown]
# Our data set now only contains 12 feature categories and no longer has any null values.

# %% [markdown]
# There are several other features in this dataset that are duplicates of another feature or engineered from other features. After identifying those features and relationships, those features will also be removed.

# %% [markdown]
# - pclass is identical to class; pclass is an int datatype of the string representation of class.

# %% [markdown]
# - survived is identical to alive; survived is an int datatype of the object representation of alive (i.e., survived is a numerical boolean representation of alive status)

# %% [markdown]
# - embarked is identical to embark_town; embark is only the first char representation of the string of embark_town

# %% [markdown]
# - adult_male is engineered from sex and age, such that if sex == male and age > 15 , then adult_male is True, else adult_male is False. (Visual investigation below.)

# %%
# visualize spread of age data for each sex and whether they were marked as an adult_male with a boxplot
plt.figure(num= 8)

sns.boxplot(data=titanic, x= 'sex', y= 'age', hue= 'adult_male')
plt.title('Age vs Sex')
plt.xlabel('Sex (M/F)')
plt.ylabel('Age (yrs)')

plt.show()

# %% [markdown]
# - who is engineered from sex and age, such that if age > 15 and sex == male, then who is man; elif age > 15 and sex == female, then who is woman; else who is child (i.e., all ages 15 and under, regardless of sex). (Visusal investigation below.)

# %%
# check options for 'who' feature
titanic.value_counts(['who'])
# Out:
# who
# man      537
# woman    269
# child     83
# Name: count, dtype: int64

# %%
# visualize spread of age data for each sex and what value for 'who' they were given
plt.figure(num= 9)

sns.boxplot(data=titanic, x= 'sex', y= 'age', hue= 'who')
plt.title('Age vs Sex')
plt.xlabel('Sex (M/F)')
plt.ylabel('Age (yrs)')

plt.show()

# %% [markdown]
# Due to their redundant nature, the following classes will be removed:
# - class
# - who
# - adult_male
# - alive
# - embarked

# %%
# remove the above classes
removed_classes= ['class', 'who', 'adult_male', 'alive', 'embarked']
titanic.drop(removed_classes, axis= 1, inplace= True)
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 889 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     889 non-null    int64
#  1   pclass       889 non-null    int64
#  2   sex          889 non-null    object
#  3   age          889 non-null    float64
#  4   sibsp        889 non-null    int64
#  5   parch        889 non-null    int64
#  6   fare         889 non-null    float64
#  7   embark_town  889 non-null    object
#  8   alone        889 non-null    bool
# dtypes: bool(1), float64(2), int64(4), object(2)
# memory usage: 63.4+ KB

# %%
# convert categorical variables (that aren't already numerically coded) to numeric dummies
dummy= pd.get_dummies(titanic, columns=['sex', 'alone', 'embark_town'], drop_first= True, dtype= float)
dummy.head()
# Out:
#    survived  pclass   age  sibsp  parch     fare  sex_male  alone_True  \
# 0         0       3  22.0      1      0   7.2500       1.0         0.0
# 1         1       1  38.0      1      0  71.2833       0.0         0.0
# 2         1       3  26.0      0      0   7.9250       0.0         1.0
# 3         1       1  35.0      1      0  53.1000       0.0         0.0
# 4         0       3  35.0      0      0   8.0500       1.0         1.0
#
#    embark_town_Queenstown  embark_town_Southampton
# 0                     0.0                      1.0
# 1                     0.0                      0.0
# 2                     0.0                      1.0
# 3                     0.0                      1.0
# 4                     0.0                      1.0

# %%
# create feature set by dropping survived
X = pd.DataFrame(dummy.drop(labels= ['survived'], axis= 1))

# %%
# resulting dataframe should include pclass, age, sibsp, parch, fare, and the categorical dummy columns
X.head()
# Out:
#    pclass   age  sibsp  parch     fare  sex_male  alone_True  \
# 0       3  22.0      1      0   7.2500       1.0         0.0
# 1       1  38.0      1      0  71.2833       0.0         0.0
# 2       3  26.0      0      0   7.9250       0.0         1.0
# 3       1  35.0      1      0  53.1000       0.0         0.0
# 4       3  35.0      0      0   8.0500       1.0         1.0
#
#    embark_town_Queenstown  embark_town_Southampton
# 0                     0.0                      1.0
# 1                     0.0                      0.0
# 2                     0.0                      1.0
# 3                     0.0                      1.0
# 4                     0.0                      1.0

# %%
# create target dataframe from the survived column of the dataset
y = pd.DataFrame(data= dummy, columns= ['survived'])
y.head()
# Out:
#    survived
# 0         0
# 1         1
# 2         1
# 3         1
# 4         0

# %%
# split clean data into a training and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= 0.20, random_state= 42, stratify= y.survived)

# %%
X_train
# Out:
#      pclass        age  sibsp  parch      fare  sex_male  alone_True  \
# 621       1  42.000000      1      0   52.5542       1.0         0.0
# 481       2  29.877630      0      0    0.0000       1.0         1.0
# 527       1  38.233441      0      0  221.7792       1.0         1.0
# 435       1  14.000000      1      2  120.0000       0.0         0.0
# 797       3  31.000000      0      0    8.6833       0.0         1.0
# ..      ...        ...    ...    ...       ...       ...         ...
# 359       3  25.140620      0      0    7.8792       0.0         1.0
# 643       3  25.140620      0      0   56.4958       1.0         1.0
# 736       3  48.000000      1      3   34.3750       0.0         0.0
# 462       1  47.000000      0      0   38.5000       1.0         1.0
# 507       1  38.233441      0      0   26.5500       1.0         1.0
#
#      embark_town_Queenstown  embark_town_Southampton
# 621                     0.0                      1.0
# 481                     0.0                      1.0
# 527                     0.0                      1.0
# 435                     0.0                      1.0
# 797                     0.0                      1.0
# ..                      ...                      ...
# 359                     1.0                      0.0
# 643                     0.0                      1.0
# 736                     0.0                      1.0
# 462                     0.0                      1.0
# 507                     0.0                      1.0
#
# [711 rows x 9 columns]

# %% [markdown]
# ## Part 3: Model Training

# %% [markdown]
# Implement a logistic regression, support vector classifier, and an sgd classifier.

# %%
# implement a logistic regression model
logreg_model = LogisticRegression(max_iter= 1000)
logreg_model_preds = cross_val_predict(estimator= logreg_model, X= X_train, y= y_train.survived, cv= 5, method= 'predict_proba')

# %%
# implement a suport vector classifier
svm_clf = svm.SVC(probability= True)
svm_clf_preds= cross_val_predict(estimator= svm_clf, X= X_train, y= y_train.survived, cv= 5, method= 'predict_proba')

# %%
# implement an sgd classifier
sgd_clf = SGDClassifier()
sgd_clf_preds = cross_val_predict(estimator= sgd_clf, X= X_train, y= y_train.survived, cv= 5, method= 'decision_function')

# %% [markdown]
# Print out classification reports, confustion matrices, and roc scores/charts for each model.

# %%
print('*** Logistic Regression ***')
print('\nConfusion Matrix:')
print(confusion_matrix(y_true= y_train, y_pred= logreg_model_preds[:, 1] >= 0.5))
print('\nClassification Report:')
print(classification_report(y_true= y_train, y_pred= logreg_model_preds[:, 1] >= 0.5))
print('\nROC-AUC Score:')
print(roc_auc_score(y_true= y_train, y_score= logreg_model_preds[:, 1]))
print('\n')
fpr, tpr, thresh = roc_curve(y_true= y_train, y_score= logreg_model_preds[:, 1])
plt.figure(figsize= (8, 8), num= 1)
plt.plot(fpr, tpr, linewidth= 2)
plt.plot([(0, 0), (1, 1)], 'k--')
plt.title('Logistic Regression ROC Curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.show()
print('\n')

print('*** Support Vector Classifier ***')
print('\nConfusion Matrix:')
print(confusion_matrix(y_true= y_train, y_pred= svm_clf_preds[:, 1] >= 0.5))
print('\nClassification Report:')
print(classification_report(y_true= y_train, y_pred= svm_clf_preds[:, 1] >= 0.5))
print('\nROC-AUC Score:')
print(roc_auc_score(y_true= y_train, y_score= svm_clf_preds[:, 1]))
print('\n')
fpr, tpr, thresh = roc_curve(y_true= y_train, y_score= svm_clf_preds[:, 1])
plt.figure(figsize= (8, 8), num= 2)
plt.plot(fpr, tpr, linewidth= 2)
plt.plot([(0, 0), (1, 1)], 'k--')
plt.title('Support Vector ROC Curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.show()
print('\n')

print('*** SGD Classifier ***')
print('\nConfusion Matrix:')
print(confusion_matrix(y_true= y_train, y_pred= sgd_clf_preds > 0))
print('\nClassification Report:')
print(classification_report(y_true= y_train, y_pred= sgd_clf_preds > 0))
print('\nROC-AUC Score:')
print(roc_auc_score(y_true= y_train, y_score= sgd_clf_preds))
fpr, tpr, thresh = roc_curve(y_true= y_train, y_score= sgd_clf_preds)
print('\n')
plt.figure(figsize= (8, 8), num= 3)
plt.plot(fpr, tpr, linewidth= 2)
plt.plot([(0, 0), (1, 1)], 'k--')
plt.title('SGD Classifier ROC Curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.show()
print('\n')
# Out:
# *** Logistic Regression ***
#
# Confusion Matrix:
# [[377  62]
#  [ 80 192]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.82      0.86      0.84       439
#            1       0.76      0.71      0.73       272
#
#     accuracy                           0.80       711
#    macro avg       0.79      0.78      0.79       711
# weighted avg       0.80      0.80      0.80       711
#
#
# ROC-AUC Score:
# 0.8472254790298808
# *** Support Vector Classifier ***
#
# Confusion Matrix:
# [[399  40]
#  [184  88]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.68      0.91      0.78       439
#            1       0.69      0.32      0.44       272
#
#     accuracy                           0.68       711
#    macro avg       0.69      0.62      0.61       711
# weighted avg       0.69      0.68      0.65       711
#
#
# ROC-AUC Score:
# 0.7196795859573897
# *** SGD Classifier ***
#
# Confusion Matrix:
# [[355  84]
#  [124 148]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.74      0.81      0.77       439
#            1       0.64      0.54      0.59       272
#
#     accuracy                           0.71       711
#    macro avg       0.69      0.68      0.68       711
# weighted avg       0.70      0.71      0.70       711
#
#
# ROC-AUC Score:
# 0.7382713051051855

# %%
plt.close('all')

# %% [markdown]
# ## Part 4: Model Tuning

# %% [markdown]
# See if scaling the input data affects the Support Vector Classifier model. Implement a sklearn pipeline to combine scaling and instanstiation of the model.

# %%
# implement a sklearn pipeline to combine scaling and instantiation of model
svm_clf_scaled = \
Pipeline([
    ('scaler', StandardScaler()),
    ('svm_clf', svm.SVC(probability= True))
])

svm_clf_scaled_preds = cross_val_predict(estimator= svm_clf_scaled, X= X_train, y= y_train.survived, cv= 5,
                                         method= 'predict_proba')

# %% [markdown]
# Print out classification reports, confustion matrices, and roc scores/charts for this model

# %%
print('*** Support Vector Classifier w/Scaled Data ***')
print('\nConfusion Matrix:')
print(confusion_matrix(y_true= y_train, y_pred= svm_clf_scaled_preds[:, 1] >= 0.5))
print('\nClassification Report:')
print(classification_report(y_true= y_train, y_pred= svm_clf_scaled_preds[:, 1] >= 0.5))
print('\nROC-AUC Score:')
print(roc_auc_score(y_true= y_train, y_score= svm_clf_scaled_preds[:, 1]))
print('\n')
fpr, tpr, thresh = roc_curve(y_true= y_train, y_score= svm_clf_scaled_preds[:, 1])
plt.figure(figsize= (8, 8), num= 4)
plt.plot(fpr, tpr, linewidth= 2)
plt.plot([(0, 0), (1, 1)], 'k--')
plt.title('Support Vector w/Scaled Data ROC Curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.show()
print('\n')
# Out:
# *** Support Vector Classifier w/Scaled Data ***
#
# Confusion Matrix:
# [[395  44]
#  [ 84 188]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.82      0.90      0.86       439
#            1       0.81      0.69      0.75       272
#
#     accuracy                           0.82       711
#    macro avg       0.82      0.80      0.80       711
# weighted avg       0.82      0.82      0.82       711
#
#
# ROC-AUC Score:
# 0.8378961208629239

# %%
plt.close(fig= 4)

# %% [markdown]
# The Support Vector Classifier performs better when the data is scaled beforehand.

# %% [markdown]
# Perform a grid search of the pipeline classifier using the following parameter grid:
# - {'kernel': ['rbf'], 'gamma': [0.0001, 0.001, 0.01, 0.1, 1], {'C': [1, 10, 50, 100, 200, 300]}

# %%
# implement a sklearn pipeline to combine scaling and instantiation of model
svm_clf_scaled = \
Pipeline([
    ('scaler', StandardScaler()),
    ('svm_clf', svm.SVC(probability= True))
])

# set up the grid
# {'kernel': ['rbf'], 'gamma': [0.0001, 0.001, 0.01, 0.1, 1], {'C': [1, 10, 50, 100, 200, 300]}'
grid = {'svm_clf__kernel': ['rbf'],
        'svm_clf__gamma': [0.0001, 0.001, 0.01, 0.1, 1],
        'svm_clf__C': [1, 10, 50, 100, 200, 300]
       }

# set up the grid search
grid_search = \
GridSearchCV(estimator= svm_clf_scaled,
             param_grid= grid,
             cv= 5,
             verbose= 5,
             scoring= 'roc_auc')

# perform the grid search
grid_search.fit(X_train, y_train.survived)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# [CV 1/5] END svm_clf__C=1, svm_clf__gamma=0.0001, svm_clf__kernel=rbf;, score=0.837 total time=   0.0s
# [CV 2/5] END svm_clf__C=1, svm_clf__gamma=0.0001, svm_clf__kernel=rbf;, score=0.829 total time=   0.0s
# [CV 3/5] END svm_clf__C=1, svm_clf__gamma=0.0001, svm_clf__kernel=rbf;, score=0.839 total time=   0.0s
# [CV 4/5] END svm_clf__C=1, svm_clf__gamma=0.0001, svm_clf__kernel=rbf;, score=0.860 total time=   0.0s
# [CV 5/5] END svm_clf__C=1, svm_clf__gamma=0.0001, svm_clf__kernel=rbf;, score=0.858 total time=   0.0s
# [CV 1/5] END svm_clf__C=1, svm_clf__gamma=0.001, svm_clf__kernel=rbf;, score=0.844 total time=   0.0s
# [CV 2/5] END svm_clf__C=1, svm_clf__gamma=0.001, svm_clf__kernel=rbf;, score=0.832 total time=   0.0s
# [CV 3/5] END svm_clf__C=1, svm_clf__gamma=0.001, svm_clf__kernel=rbf;, score=0.839 total time=   0.0s
# [CV 4/5] END svm_clf__C=1, svm_clf__gamma=0.001, svm_clf__kernel=rbf;, score=0.862 total time=   0.0s
# [CV 5/5] END svm_clf__C=1, svm_clf__gamma=0.001, svm_clf__kernel=rbf;, score=0.858 total time=   0.0s
# [CV 1/5] END svm_clf__C=1, svm_clf__gamma=0.01, svm_clf__kernel=rbf;, score=0.858 total time=   0.0s
# [CV 2/5] END svm_clf__C=1, svm_clf__gamma=0.01, svm_clf__kernel=rbf;, score=0.843 total time=   0.0s
# [CV 3/5] END svm_clf__C=1, svm_clf__gamma=0.01, svm_clf__kernel=rbf;, score=0.828 total time=   0.0s
# [CV 4/5] END svm_clf__C=1, svm_clf__gamma=0.01, svm_clf__kernel=rbf;, score=0.842 total time=   0.0s
# [CV 5/5] END svm_clf__C=1, svm_clf__gamma=0.01, svm_clf__kernel=rbf;, score=0.849 total time=   0.0s
# [CV 1/5] END svm_clf__C=1, svm_clf__gamma=0.1, svm_clf__kernel=rbf;, score=0.865 total time=   0.0s
# [CV 2/5] END svm_clf__C=1, svm_clf__gamma=0.1, svm_clf__kernel=rbf;, score=0.818 total time=   0.0s
# [CV 3/5] END svm_clf__C=1, svm_clf__gamma=0.1, svm_clf__kernel=rbf;, score=0.844 total time=   0.0s
# [CV 4/5] END svm_clf__C=1, svm_clf__gamma=0.1, svm_clf__kernel=rbf;, score=0.842 total time=   0.0s
# [CV 5/5] END svm_clf__C=1, svm_clf__gamma=0.1, svm_clf__kernel=rbf;, score=0.880 total time=   0.0s
# [CV 1/5] END svm_clf__C=1, svm_clf__gamma=1, svm_clf__kernel=rbf;, score=0.821 total time=   0.0s
# [CV 2/5] END svm_clf__C=1, svm_clf__gamma=1, svm_clf__kernel=rbf;, score=0.774 total time=   0.0s
# [CV 3/5] END svm_clf__C=1, svm_clf__gamma=1, svm_clf__kernel=rbf;, score=0.806 total time=   0.0s
# [CV 4/5] END svm_clf__C=1, svm_clf__gamma=1, svm_clf__kernel=rbf;, score=0.818 total time=   0.0s
# [CV 5/5] END svm_clf__C=1, svm_clf__gamma=1, svm_clf__kernel=rbf;, score=0.819 total time=   0.0s
# [CV 1/5] END svm_clf__C=10, svm_clf__gamma=0.0001, svm_clf__kernel=rbf;, score=0.845 total time=   0.0s
# [CV 2/5] END svm_clf__C=10, svm_clf__gamma=0.0001, svm_clf__kernel=rbf;, score=0.833 total time=   0.0s
# [CV 3/5] END svm_clf__C=10, svm_clf__gamma=0.0001, svm_clf__kernel=rbf;, score=0.840 total time=   0.0s
# [CV 4/5] END svm_clf__C=10, svm_clf__gamma=0.0001, svm_clf__kernel=rbf;, score=0.861 total time=   0.0s
# [CV 5/5] END svm_clf__C=10, svm_clf__gamma=0.0001, svm_clf__kernel=rbf;, score=0.858 total time=   0.0s
# [CV 1/5] END svm_clf__C=10, svm_clf__gamma=0.001, svm_clf__kernel=rbf;, score=0.849 total time=   0.0s
# [CV 2/5] END svm_clf__C=10, svm_clf__gamma=0.001, svm_clf__kernel=rbf;, score=0.828 total time=   0.0s
# [CV 3/5] END svm_clf__C=10, svm_clf__gamma=0.001, svm_clf__kernel=rbf;, score=0.834 total time=   0.0s
# [CV 4/5] END svm_clf__C=10, svm_clf__gamma=0.001, svm_clf__kernel=rbf;, score=0.816 total time=   0.0s
# [CV 5/5] END svm_clf__C=10, svm_clf__gamma=0.001, svm_clf__kernel=rbf;, score=0.842 total time=   0.0s
# [CV 1/5] END svm_clf__C=10, svm_clf__gamma=0.01, svm_clf__kernel=rbf;, score=0.851 total time=   0.0s
# [CV 2/5] END svm_clf__C=10, svm_clf__gamma=0.01, svm_clf__kernel=rbf;, score=0.845 total time=   0.0s
# [CV 3/5] END svm_clf__C=10, svm_clf__gamma=0.01, svm_clf__kernel=rbf;, score=0.847 total time=   0.0s
# [CV 4/5] END svm_clf__C=10, svm_clf__gamma=0.01, svm_clf__kernel=rbf;, score=0.825 total time=   0.0s
# [CV 5/5] END svm_clf__C=10, svm_clf__gamma=0.01, svm_clf__kernel=rbf;, score=0.824 total time=   0.0s
# [CV 1/5] END svm_clf__C=10, svm_clf__gamma=0.1, svm_clf__kernel=rbf;, score=0.874 total time=   0.0s
# [CV 2/5] END svm_clf__C=10, svm_clf__gamma=0.1, svm_clf__kernel=rbf;, score=0.810 total time=   0.0s
# [CV 3/5] END svm_clf__C=10, svm_clf__gamma=0.1, svm_clf__kernel=rbf;, score=0.826 total time=   0.0s
# [CV 4/5] END svm_clf__C=10, svm_clf__gamma=0.1, svm_clf__kernel=rbf;, score=0.807 total time=   0.0s
# [CV 5/5] END svm_clf__C=10, svm_clf__gamma=0.1, svm_clf__kernel=rbf;, score=0.870 total time=   0.0s
# [CV 1/5] END svm_clf__C=10, svm_clf__gamma=1, svm_clf__kernel=rbf;, score=0.746 total time=   0.0s
# [CV 2/5] END svm_clf__C=10, svm_clf__gamma=1, svm_clf__kernel=rbf;, score=0.763 total time=   0.0s
# [CV 3/5] END svm_clf__C=10, svm_clf__gamma=1, svm_clf__kernel=rbf;, score=0.808 total time=   0.0s
# [CV 4/5] END svm_clf__C=10, svm_clf__gamma=1, svm_clf__kernel=rbf;, score=0.764 total time=   0.0s
# [CV 5/5] END svm_clf__C=10, svm_clf__gamma=1, svm_clf__kernel=rbf;, score=0.829 total time=   0.0s
# [CV 1/5] END svm_clf__C=50, svm_clf__gamma=0.0001, svm_clf__kernel=rbf;, score=0.858 total time=   0.0s
# [CV 2/5] END svm_clf__C=50, svm_clf__gamma=0.0001, svm_clf__kernel=rbf;, score=0.828 total time=   0.0s
# [CV 3/5] END svm_clf__C=50, svm_clf__gamma=0.0001, svm_clf__kernel=rbf;, score=0.846 total time=   0.0s
# [CV 4/5] END svm_clf__C=50, svm_clf__gamma=0.0001, svm_clf__kernel=rbf;, score=0.837 total time=   0.0s
# [CV 5/5] END svm_clf__C=50, svm_clf__gamma=0.0001, svm_clf__kernel=rbf;, score=0.860 total time=   0.0s
# [CV 1/5] END svm_clf__C=50, svm_clf__gamma=0.001, svm_clf__kernel=rbf;, score=0.848 total time=   0.0s
# [CV 2/5] END svm_clf__C=50, svm_clf__gamma=0.001, svm_clf__kernel=rbf;, score=0.836 total time=   0.0s
# [CV 3/5] END svm_clf__C=50, svm_clf__gamma=0.001, svm_clf__kernel=rbf;, score=0.817 total time=   0.0s
# [CV 4/5] END svm_clf__C=50, svm_clf__gamma=0.001, svm_clf__kernel=rbf;, score=0.811 total time=   0.0s
# [CV 5/5] END svm_clf__C=50, svm_clf__gamma=0.001, svm_clf__kernel=rbf;, score=0.836 total time=   0.0s
# [CV 1/5] END svm_clf__C=50, svm_clf__gamma=0.01, svm_clf__kernel=rbf;, score=0.864 total time=   0.0s
# [CV 2/5] END svm_clf__C=50, svm_clf__gamma=0.01, svm_clf__kernel=rbf;, score=0.834 total time=   0.0s
# [CV 3/5] END svm_clf__C=50, svm_clf__gamma=0.01, svm_clf__kernel=rbf;, score=0.860 total time=   0.0s
# [CV 4/5] END svm_clf__C=50, svm_clf__gamma=0.01, svm_clf__kernel=rbf;, score=0.818 total time=   0.0s
# [CV 5/5] END svm_clf__C=50, svm_clf__gamma=0.01, svm_clf__kernel=rbf;, score=0.827 total time=   0.0s
# [CV 1/5] END svm_clf__C=50, svm_clf__gamma=0.1, svm_clf__kernel=rbf;, score=0.832 total time=   0.0s
# [CV 2/5] END svm_clf__C=50, svm_clf__gamma=0.1, svm_clf__kernel=rbf;, score=0.752 total time=   0.0s
# [CV 3/5] END svm_clf__C=50, svm_clf__gamma=0.1, svm_clf__kernel=rbf;, score=0.820 total time=   0.0s
# [CV 4/5] END svm_clf__C=50, svm_clf__gamma=0.1, svm_clf__kernel=rbf;, score=0.799 total time=   0.0s
# [CV 5/5] END svm_clf__C=50, svm_clf__gamma=0.1, svm_clf__kernel=rbf;, score=0.841 total time=   0.0s
# [CV 1/5] END svm_clf__C=50, svm_clf__gamma=1, svm_clf__kernel=rbf;, score=0.743 total time=   0.0s
# [CV 2/5] END svm_clf__C=50, svm_clf__gamma=1, svm_clf__kernel=rbf;, score=0.725 total time=   0.0s
# [CV 3/5] END svm_clf__C=50, svm_clf__gamma=1, svm_clf__kernel=rbf;, score=0.794 total time=   0.0s
# [CV 4/5] END svm_clf__C=50, svm_clf__gamma=1, svm_clf__kernel=rbf;, score=0.751 total time=   0.0s
# [CV 5/5] END svm_clf__C=50, svm_clf__gamma=1, svm_clf__kernel=rbf;, score=0.792 total time=   0.0s
# [CV 1/5] END svm_clf__C=100, svm_clf__gamma=0.0001, svm_clf__kernel=rbf;, score=0.848 total time=   0.0s
# [CV 2/5] END svm_clf__C=100, svm_clf__gamma=0.0001, svm_clf__kernel=rbf;, score=0.827 total time=   0.0s
# [CV 3/5] END svm_clf__C=100, svm_clf__gamma=0.0001, svm_clf__kernel=rbf;, score=0.831 total time=   0.0s
# [CV 4/5] END svm_clf__C=100, svm_clf__gamma=0.0001, svm_clf__kernel=rbf;, score=0.802 total time=   0.0s
# [CV 5/5] END svm_clf__C=100, svm_clf__gamma=0.0001, svm_clf__kernel=rbf;, score=0.843 total time=   0.0s
# [CV 1/5] END svm_clf__C=100, svm_clf__gamma=0.001, svm_clf__kernel=rbf;, score=0.857 total time=   0.0s
# [CV 2/5] END svm_clf__C=100, svm_clf__gamma=0.001, svm_clf__kernel=rbf;, score=0.847 total time=   0.0s
# [CV 3/5] END svm_clf__C=100, svm_clf__gamma=0.001, svm_clf__kernel=rbf;, score=0.821 total time=   0.0s
# [CV 4/5] END svm_clf__C=100, svm_clf__gamma=0.001, svm_clf__kernel=rbf;, score=0.813 total time=   0.0s
# [CV 5/5] END svm_clf__C=100, svm_clf__gamma=0.001, svm_clf__kernel=rbf;, score=0.833 total time=   0.0s
# [CV 1/5] END svm_clf__C=100, svm_clf__gamma=0.01, svm_clf__kernel=rbf;, score=0.869 total time=   0.0s
# [CV 2/5] END svm_clf__C=100, svm_clf__gamma=0.01, svm_clf__kernel=rbf;, score=0.828 total time=   0.0s
# [CV 3/5] END svm_clf__C=100, svm_clf__gamma=0.01, svm_clf__kernel=rbf;, score=0.873 total time=   0.0s
# [CV 4/5] END svm_clf__C=100, svm_clf__gamma=0.01, svm_clf__kernel=rbf;, score=0.821 total time=   0.0s
# [CV 5/5] END svm_clf__C=100, svm_clf__gamma=0.01, svm_clf__kernel=rbf;, score=0.849 total time=   0.0s
# [CV 1/5] END svm_clf__C=100, svm_clf__gamma=0.1, svm_clf__kernel=rbf;, score=0.809 total time=   0.0s
# [CV 2/5] END svm_clf__C=100, svm_clf__gamma=0.1, svm_clf__kernel=rbf;, score=0.742 total time=   0.0s
# [CV 3/5] END svm_clf__C=100, svm_clf__gamma=0.1, svm_clf__kernel=rbf;, score=0.818 total time=   0.0s
# [CV 4/5] END svm_clf__C=100, svm_clf__gamma=0.1, svm_clf__kernel=rbf;, score=0.796 total time=   0.0s
# [CV 5/5] END svm_clf__C=100, svm_clf__gamma=0.1, svm_clf__kernel=rbf;, score=0.845 total time=   0.0s
# [CV 1/5] END svm_clf__C=100, svm_clf__gamma=1, svm_clf__kernel=rbf;, score=0.740 total time=   0.0s
# [CV 2/5] END svm_clf__C=100, svm_clf__gamma=1, svm_clf__kernel=rbf;, score=0.706 total time=   0.0s
# [CV 3/5] END svm_clf__C=100, svm_clf__gamma=1, svm_clf__kernel=rbf;, score=0.795 total time=   0.0s
# [CV 4/5] END svm_clf__C=100, svm_clf__gamma=1, svm_clf__kernel=rbf;, score=0.737 total time=   0.0s
# [CV 5/5] END svm_clf__C=100, svm_clf__gamma=1, svm_clf__kernel=rbf;, score=0.798 total time=   0.0s
# [CV 1/5] END svm_clf__C=200, svm_clf__gamma=0.0001, svm_clf__kernel=rbf;, score=0.842 total time=   0.0s
# [CV 2/5] END svm_clf__C=200, svm_clf__gamma=0.0001, svm_clf__kernel=rbf;, score=0.813 total time=   0.0s
# [CV 3/5] END svm_clf__C=200, svm_clf__gamma=0.0001, svm_clf__kernel=rbf;, score=0.799 total time=   0.0s
# [CV 4/5] END svm_clf__C=200, svm_clf__gamma=0.0001, svm_clf__kernel=rbf;, score=0.796 total time=   0.0s
# [CV 5/5] END svm_clf__C=200, svm_clf__gamma=0.0001, svm_clf__kernel=rbf;, score=0.842 total time=   0.0s
# [CV 1/5] END svm_clf__C=200, svm_clf__gamma=0.001, svm_clf__kernel=rbf;, score=0.865 total time=   0.0s
# [CV 2/5] END svm_clf__C=200, svm_clf__gamma=0.001, svm_clf__kernel=rbf;, score=0.854 total time=   0.0s
# [CV 3/5] END svm_clf__C=200, svm_clf__gamma=0.001, svm_clf__kernel=rbf;, score=0.828 total time=   0.0s
# [CV 4/5] END svm_clf__C=200, svm_clf__gamma=0.001, svm_clf__kernel=rbf;, score=0.820 total time=   0.0s
# [CV 5/5] END svm_clf__C=200, svm_clf__gamma=0.001, svm_clf__kernel=rbf;, score=0.824 total time=   0.0s
# [CV 1/5] END svm_clf__C=200, svm_clf__gamma=0.01, svm_clf__kernel=rbf;, score=0.873 total time=   0.0s
# [CV 2/5] END svm_clf__C=200, svm_clf__gamma=0.01, svm_clf__kernel=rbf;, score=0.827 total time=   0.0s
# [CV 3/5] END svm_clf__C=200, svm_clf__gamma=0.01, svm_clf__kernel=rbf;, score=0.872 total time=   0.0s
# [CV 4/5] END svm_clf__C=200, svm_clf__gamma=0.01, svm_clf__kernel=rbf;, score=0.818 total time=   0.0s
# [CV 5/5] END svm_clf__C=200, svm_clf__gamma=0.01, svm_clf__kernel=rbf;, score=0.847 total time=   0.0s
# [CV 1/5] END svm_clf__C=200, svm_clf__gamma=0.1, svm_clf__kernel=rbf;, score=0.801 total time=   0.0s
# [CV 2/5] END svm_clf__C=200, svm_clf__gamma=0.1, svm_clf__kernel=rbf;, score=0.752 total time=   0.0s
# [CV 3/5] END svm_clf__C=200, svm_clf__gamma=0.1, svm_clf__kernel=rbf;, score=0.808 total time=   0.0s
# [CV 4/5] END svm_clf__C=200, svm_clf__gamma=0.1, svm_clf__kernel=rbf;, score=0.798 total time=   0.0s
# [CV 5/5] END svm_clf__C=200, svm_clf__gamma=0.1, svm_clf__kernel=rbf;, score=0.838 total time=   0.0s
# [CV 1/5] END svm_clf__C=200, svm_clf__gamma=1, svm_clf__kernel=rbf;, score=0.740 total time=   0.0s
# [CV 2/5] END svm_clf__C=200, svm_clf__gamma=1, svm_clf__kernel=rbf;, score=0.701 total time=   0.1s
# [CV 3/5] END svm_clf__C=200, svm_clf__gamma=1, svm_clf__kernel=rbf;, score=0.794 total time=   0.0s
# [CV 4/5] END svm_clf__C=200, svm_clf__gamma=1, svm_clf__kernel=rbf;, score=0.729 total time=   0.0s
# [CV 5/5] END svm_clf__C=200, svm_clf__gamma=1, svm_clf__kernel=rbf;, score=0.807 total time=   0.0s
# [CV 1/5] END svm_clf__C=300, svm_clf__gamma=0.0001, svm_clf__kernel=rbf;, score=0.841 total time=   0.0s
# [CV 2/5] END svm_clf__C=300, svm_clf__gamma=0.0001, svm_clf__kernel=rbf;, score=0.819 total time=   0.0s
# [CV 3/5] END svm_clf__C=300, svm_clf__gamma=0.0001, svm_clf__kernel=rbf;, score=0.822 total time=   0.0s
# [CV 4/5] END svm_clf__C=300, svm_clf__gamma=0.0001, svm_clf__kernel=rbf;, score=0.794 total time=   0.0s
# [CV 5/5] END svm_clf__C=300, svm_clf__gamma=0.0001, svm_clf__kernel=rbf;, score=0.837 total time=   0.0s
# [CV 1/5] END svm_clf__C=300, svm_clf__gamma=0.001, svm_clf__kernel=rbf;, score=0.856 total time=   0.0s
# [CV 2/5] END svm_clf__C=300, svm_clf__gamma=0.001, svm_clf__kernel=rbf;, score=0.842 total time=   0.0s
# [CV 3/5] END svm_clf__C=300, svm_clf__gamma=0.001, svm_clf__kernel=rbf;, score=0.832 total time=   0.0s
# [CV 4/5] END svm_clf__C=300, svm_clf__gamma=0.001, svm_clf__kernel=rbf;, score=0.801 total time=   0.0s
# [CV 5/5] END svm_clf__C=300, svm_clf__gamma=0.001, svm_clf__kernel=rbf;, score=0.823 total time=   0.0s
# [CV 1/5] END svm_clf__C=300, svm_clf__gamma=0.01, svm_clf__kernel=rbf;, score=0.867 total time=   0.0s
# [CV 2/5] END svm_clf__C=300, svm_clf__gamma=0.01, svm_clf__kernel=rbf;, score=0.822 total time=   0.0s
# [CV 3/5] END svm_clf__C=300, svm_clf__gamma=0.01, svm_clf__kernel=rbf;, score=0.871 total time=   0.0s
# [CV 4/5] END svm_clf__C=300, svm_clf__gamma=0.01, svm_clf__kernel=rbf;, score=0.807 total time=   0.0s
# [CV 5/5] END svm_clf__C=300, svm_clf__gamma=0.01, svm_clf__kernel=rbf;, score=0.823 total time=   0.0s
# [CV 1/5] END svm_clf__C=300, svm_clf__gamma=0.1, svm_clf__kernel=rbf;, score=0.791 total time=   0.1s
# [CV 2/5] END svm_clf__C=300, svm_clf__gamma=0.1, svm_clf__kernel=rbf;, score=0.753 total time=   0.1s
# [CV 3/5] END svm_clf__C=300, svm_clf__gamma=0.1, svm_clf__kernel=rbf;, score=0.774 total time=   0.1s
# [CV 4/5] END svm_clf__C=300, svm_clf__gamma=0.1, svm_clf__kernel=rbf;, score=0.797 total time=   0.0s
# [CV 5/5] END svm_clf__C=300, svm_clf__gamma=0.1, svm_clf__kernel=rbf;, score=0.849 total time=   0.1s
# [CV 1/5] END svm_clf__C=300, svm_clf__gamma=1, svm_clf__kernel=rbf;, score=0.737 total time=   0.0s
# [CV 2/5] END svm_clf__C=300, svm_clf__gamma=1, svm_clf__kernel=rbf;, score=0.702 total time=   0.0s
# [CV 3/5] END svm_clf__C=300, svm_clf__gamma=1, svm_clf__kernel=rbf;, score=0.789 total time=   0.0s
# [CV 4/5] END svm_clf__C=300, svm_clf__gamma=1, svm_clf__kernel=rbf;, score=0.729 total time=   0.0s
# [CV 5/5] END svm_clf__C=300, svm_clf__gamma=1, svm_clf__kernel=rbf;, score=0.816 total time=   0.1s
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('scaler', StandardScaler()),
#                                        ('svm_clf', SVC(probability=True))]),
#              param_grid={'svm_clf__C': [1, 10, 50, 100, 200, 300],
#                          'svm_clf__gamma': [0.0001, 0.001, 0.01, 0.1, 1],
#                          'svm_clf__kernel': ['rbf']},
#              scoring='roc_auc', verbose=5)

# %%
# print the best estimator, its parameters and the resulting score
print(f'Best estimator: {grid_search.best_estimator_}')
print(f'Best parameters: {grid_search.best_params_}')
print(f'Best ROC-AUC score: {grid_search.best_score_}')
# Out:
# Best estimator: Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svm_clf', SVC(C=1, gamma=0.1, probability=True))])
# Best parameters: {'svm_clf__C': 1, 'svm_clf__gamma': 0.1, 'svm_clf__kernel': 'rbf'}
# Best ROC-AUC score: 0.8495547428306048

# %%
# apply this estimator to your test set
best_svm_clf_scaled_preds = grid_search.predict_proba(X_test)[:, 1]

# %%
best_svm_clf_scaled_preds
# Out:
# array([0.09426942, 0.15883187, 0.15883187, 0.15458786, 0.0640032 ,
#        0.91631714, 0.15384346, 0.82213671, 0.89367971, 0.15582652,
#        0.15883187, 0.87794173, 0.87955915, 0.88885332, 0.9421298 ,
#        0.78770192, 0.84882718, 0.85567493, 0.15752344, 0.15565425,
#        0.15879309, 0.15713022, 0.16019867, 0.15732215, 0.20814688,
#        0.81213942, 0.65326199, 0.84312771, 0.15389411, 0.89612824,
#        0.94627605, 0.14812303, 0.15399716, 0.1540085 , 0.29157009,
#        0.15890482, 0.15663755, 0.15459881, 0.13901213, 0.16229521,
#        0.90265513, 0.20356503, 0.84773987, 0.89884808, 0.09553319,
#        0.06397672, 0.8514545 , 0.15899862, 0.15514818, 0.16597561,
#        0.10390126, 0.16079972, 0.15388574, 0.83347087, 0.66990722,
#        0.15170931, 0.23146046, 0.5       , 0.15964085, 0.15879776,
#        0.15439792, 0.17293874, 0.1572907 , 0.15686486, 0.89878948,
#        0.15840695, 0.15194188, 0.42315022, 0.15314222, 0.53404793,
#        0.76438089, 0.15280922, 0.63179096, 0.15399716, 0.31053969,
#        0.20445152, 0.14916483, 0.17549   , 0.40891096, 0.1064605 ,
#        0.15888174, 0.35389108, 0.26877988, 0.15550947, 0.86857624,
#        0.17865317, 0.94673008, 0.22635267, 0.15878457, 0.15964542,
#        0.15393458, 0.27358476, 0.91942819, 0.15657983, 0.15883187,
#        0.15732215, 0.86777878, 0.15820166, 0.84979589, 0.90742028,
#        0.15504251, 0.1539408 , 0.16279951, 0.16339095, 0.15393458,
#        0.15747218, 0.38490153, 0.15883187, 0.15884785, 0.87654226,
#        0.17784813, 0.15402343, 0.15883187, 0.16253777, 0.16273786,
#        0.1098238 , 0.15820166, 0.15428987, 0.80542859, 0.15905389,
#        0.13444947, 0.15877412, 0.13330125, 0.27304117, 0.45304152,
#        0.15405323, 0.21521306, 0.10544078, 0.63131202, 0.18455192,
#        0.15424586, 0.1572907 , 0.15894197, 0.85219852, 0.15693509,
#        0.84226195, 0.15883187, 0.63232732, 0.83717161, 0.26951129,
#        0.16309544, 0.6751768 , 0.25864619, 0.46377035, 0.88590711,
#        0.15393458, 0.17663556, 0.30547704, 0.85352115, 0.89146351,
#        0.21711717, 0.94193245, 0.83397654, 0.15622676, 0.89998311,
#        0.15125998, 0.10450348, 0.45233612, 0.91995471, 0.94719656,
#        0.86339452, 0.22803677, 0.15887036, 0.85148876, 0.63370933,
#        0.15524944, 0.15738329, 0.84979589, 0.92073909, 0.15951425,
#        0.15890482, 0.16327101, 0.16792368, 0.77251775, 0.15635672,
#        0.15110263, 0.95759045, 0.17378124])

# %%
print('*** Best Support Vector Classifier w/Test Data ***')
print('\nConfusion Matrix:')
print(confusion_matrix(y_true= y_test, y_pred= best_svm_clf_scaled_preds >= 0.5))
print('\nClassification Report:')
print(classification_report(y_true= y_test, y_pred= best_svm_clf_scaled_preds >= 0.5))
print('\nROC-AUC Score:')
print(roc_auc_score(y_true= y_test, y_score= best_svm_clf_scaled_preds))
print('\n')
fpr, tpr, thresh = roc_curve(y_true= y_test, y_score= best_svm_clf_scaled_preds)
plt.figure(figsize= (8, 8), num= 5)
plt.plot(fpr, tpr, linewidth= 2)
plt.plot([(0, 0), (1, 1)], 'k--')
plt.title('Best Support Vector w/Test Data ROC Curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.show()
print('\n')
# Out:
# *** Best Support Vector Classifier w/Test Data ***
#
# Confusion Matrix:
# [[101   9]
#  [ 22  46]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.82      0.92      0.87       110
#            1       0.84      0.68      0.75        68
#
#     accuracy                           0.83       178
#    macro avg       0.83      0.80      0.81       178
# weighted avg       0.83      0.83      0.82       178
#
#
# ROC-AUC Score:
# 0.843716577540107

# %%
plt.close(fig= 5)
